# %%
from graphillion import GraphSet, tutorial
from tutorial_util import draw_zdd

grid = tutorial.grid(2, 2)
GraphSet.set_universe(grid)

paths = GraphSet.paths(1, 9)

# %%
draw_zdd(paths)
